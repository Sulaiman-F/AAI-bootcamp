# %% [markdown]
# Name : Sulaiman ALfawzan

# %% [markdown]
# ## Exercises

# %%
# This cell tells Jupyter to provide detailed debugging information
# when a runtime error occurs. Run it before working on the exercises.

# %xmode Verbose
# Out:
# Exception reporting mode: Verbose

# %% [markdown]
# For the exercises below, there are a few more turtle functions you might want to use.
#
# * `penup` lifts the turtle's imaginary pen so it doesn't leave a trail when it moves.
#
# * `pendown` puts the pen back down.
#
# The following function uses `penup` and `pendown` to move the turtle without leaving a trail.

# %%
from jupyturtle import penup, pendown

def jump(length):
    """Move forward length units without leaving a trail.

    Postcondition: Leaves the pen down.
    """
    penup()
    forward(length)
    pendown()

# %% [markdown]
# ### Exercise
#
# Write a function called `rectangle` that draws a rectangle with given side lengths.
# For example, here's a rectangle that's `80` units wide and `40` units tall.

# %%
from jupyturtle import make_turtle, forward, left

def rectangle(width, height):
    for i in range(2):
        forward(width)
        left(90)
        forward(height)
        left(90)

# %% [markdown]
# You can use the following code to test your function.

# %%
make_turtle()
rectangle(80, 40)
# Out:
# <svg width="300" height="150" style="fill:none; stroke-linecap:round;">
#     <rect width="100%" height="100%" fill="#F3F3F7" />
#
#
# <path stroke="#663399" stroke-width="2" d="M 150,75 230,75 230,35 150,35 150,75" />'
#
# <g transform="rotate(-90.0,150.0,75.0) translate(150.0, 75.0)">
#     <circle stroke="#63A375" stroke-width="2" fill="transparent" r="5.5" cx="0" cy="0"/>
#     <polygon points="0,12 2,9 -2,9" style="fill:#63A375;stroke:#63A375;stroke-width:2"/>
# </g>
#
# </svg>

# %% [markdown]
# ### Exercise
#
# Write a function called `rhombus` that draws a rhombus with a given side length and a given interior angle. For example, here's a rhombus with side length `50` and an interior angle of `60` degrees.

# %%
def rhombus(length, angle):
    for i in range(2):
        forward(length)
        left(180 - angle)
        forward(length)
        left(angle)

# %% [markdown]
# You can use the following code to test your function.

# %%
make_turtle()
rhombus(50, 50)
# Out:
# <svg width="300" height="150" style="fill:none; stroke-linecap:round;">
#     <rect width="100%" height="100%" fill="#F3F3F7" />
#
#
# <path stroke="#663399" stroke-width="2" d="M 150,75 200,75 167.9,36.7 117.9,36.7 150,75" />'
#
# <g transform="rotate(-90.0,150.0,75.0) translate(150.0, 75.0)">
#     <circle stroke="#63A375" stroke-width="2" fill="transparent" r="5.5" cx="0" cy="0"/>
#     <polygon points="0,12 2,9 -2,9" style="fill:#63A375;stroke:#63A375;stroke-width:2"/>
# </g>
#
# </svg>

# %% [markdown]
# ### Exercise
#
# Now write a more general function called `parallelogram` that draws a quadrilateral with parallel sides. Then rewrite `rectangle` and `rhombus` to use `parallelogram`.

# %%
from jupyturtle import make_turtle, forward, left, penup, pendown

def parallelogram(width, height, angle):
    for i in range(2):
        forward(width)
        left(180 - angle)
        forward(height)
        left(angle)

# %%
def rectangle(width, height):
    parallelogram(width, height, 90)

# %%
def rhombus(side, angle):
    parallelogram(side, side, angle)

# %%
def jump(length):
    """Move forward without drawing."""
    penup()
    forward(length)
    pendown()

# %% [markdown]
# You can use the following code to test your functions.

# %%
make_turtle(width=400)
jump(-120)

rectangle(80, 40)
jump(100)
rhombus(50, 60)
jump(80)
parallelogram(80, 50, 60)
# Out:
# <svg width="400" height="150" style="fill:none; stroke-linecap:round;">
#     <rect width="100%" height="100%" fill="#F3F3F7" />
#
#
# <path stroke="#663399" stroke-width="2" d="M 200,75" />'
#
# <path stroke="#663399" stroke-width="2" d="M 80,75 160,75 160,35 80,35 80,75" />'
#
# <path stroke="#663399" stroke-width="2" d="M 180,75 230,75 205,31.7 155,31.7 180,75" />'
#
# <path stroke="#663399" stroke-width="2" d="M 260,75 340,75 315,31.7 235,31.7 260,75" />'
#
# <g transform="rotate(-90.0,260.0,75.0) translate(260.0, 75.0)">
#     <circle stroke="#63A375" stroke-width="2" fill="transparent" r="5.5" cx="0" cy="0"/>
#     <polygon points="0,12 2,9 -2,9" style="fill:#63A375;stroke:#63A375;stroke-width:2"/>
# </g>
#
# </svg>

# %% [markdown]
# ### Exercise
#
# Write an appropriately general set of functions that can draw shapes like this.
#
# ![](https://github.com/AllenDowney/ThinkPython/raw/v3/jupyturtle_pie.png)
#
# Hint: Write a function called `triangle` that draws one triangular segment, and then a function called `draw_pie` that uses `triangle`.

# %%
from jupyturtle import make_turtle, forward, left
def trinagle(side):
    for i in range(3):
        forward(side)
        left(120)
# Out:
# <svg width="300" height="150" style="fill:none; stroke-linecap:round;">
#     <rect width="100%" height="100%" fill="#F3F3F7" />
#
#
# <path stroke="#663399" stroke-width="2" d="M 150,75 250,75 200,-11.6 150,75 250,75 200,-11.6 150,75" />'
#
# <g transform="rotate(-90.0,150.0,75.0) translate(150.0, 75.0)">
#     <circle stroke="#63A375" stroke-width="2" fill="transparent" r="5.5" cx="0" cy="0"/>
#     <polygon points="0,12 2,9 -2,9" style="fill:#63A375;stroke:#63A375;stroke-width:2"/>
# </g>
#
# </svg>

# %%
def draw_pie(n,size):
    dgree = 360/n
    for i in range(n):
        trinagle(size)
        left(dgree)

# %% [markdown]
# You can use the following code to test your functions.

# %%
turtle = make_turtle(delay=0)
jump(-80)

size = 40
draw_pie(5, size)
jump(2*size)
draw_pie(6, size)
jump(2*size)
draw_pie(7, size)
# Out:
# <svg width="300" height="150" style="fill:none; stroke-linecap:round;">
#     <rect width="100%" height="100%" fill="#F3F3F7" />
#
#
# <path stroke="#663399" stroke-width="2" d="M 150,75" />'
#
# <path stroke="#663399" stroke-width="2" d="M 70,75 110,75 90,40.4 70,75 82.4,37 43.2,45.3 70,75 37.6,51.5 33.5,91.3 70,75 37.6,98.5 74.2,114.8 70,75 82.4,113 109.1,83.3 70,75" />'
#
# <path stroke="#663399" stroke-width="2" d="M 150,75 190,75 170,40.4 150,75 170,40.4 130,40.4 150,75 130,40.4 110,75 150,75 110,75 130,109.6 150,75 130,109.6 170,109.6 150,75 170,109.6 190,75 150,75" />'
#
# <path stroke="#663399" stroke-width="2" d="M 230,75 270,75 250,40.4 230,75 254.9,43.7 215.4,37.8 230,75 221.1,36 191.8,63.2 230,75 194,57.6 197,97.5 230,75 194,92.4 227,114.9 230,75 221.1,114 259.3,102.2 230,75 254.9,106.3 269.6,69 230,75" />'
#
# <g transform="rotate(270.0,230.0,75.0) translate(230.0, 75.0)">
#     <circle stroke="#63A375" stroke-width="2" fill="transparent" r="5.5" cx="0" cy="0"/>
#     <polygon points="0,12 2,9 -2,9" style="fill:#63A375;stroke:#63A375;stroke-width:2"/>
# </g>
#
# </svg>

# %%
# Solution goes here

# %% [markdown]
# ### Exercise
#
# Write an appropriately general set of functions that can draw flowers like this.
#
# ![](https://github.com/AllenDowney/ThinkPython/raw/v3/jupyturtle_flower.png)
#
# Hint: Use `arc` to write a function called `petal` that draws one flower petal.

# %%
import math
from jupyturtle import make_turtle, forward, left

def arc(radius, angle):
    n = max(1, int(angle / 3))
    step_length = 2 * radius * math.sin(math.radians(angle / n) / 2)
    step_angle = angle / n
    for i in range(n):
        forward(step_length)
        left(step_angle)

def petal(radius, angle):
    arc(radius, angle)
    left(180 - angle)
    arc(radius, angle)
    left(180 - angle)

# %%
def flower(n, radius, angle):
    for i in range(n):
        petal(radius, angle)
        left(360 / n)

# %% [markdown]
# You can use the following code to test your functions.
#
# Because the solution draws a lot of small line segments, it tends to slow down as it runs.
# To avoid that, you can add the keyword argument `auto_render=False` to avoid drawing after every step, and then call the `render` function at the end to show the result.
#
# While you are debugging, you might want to remove `auto_render=False`.

# %%
make_turtle()

jump(-60)
n = 7
radius = 60
angle = 60
flower(n, radius, angle)

jump(120)
n = 9
radius = 40
angle = 85
flower(n, radius, angle)
# Out:
# <svg width="300" height="150" style="fill:none; stroke-linecap:round;">
#     <rect width="100%" height="100%" fill="#F3F3F7" />
#
#
# <path stroke="#663399" stroke-width="2" d="M 150,75" />'
#
# <path stroke="#663399" stroke-width="2" d="M 90,75 93.1,75 96.3,74.8 99.4,74.5 102.5,74 105.6,73.4 108.6,72.5 111.6,71.6 114.5,70.5 117.4,69.2 120.2,67.7 122.9,66.2 125.6,64.5 128.1,62.6 130.5,60.6 132.9,58.5 135.1,56.3 137.2,54 139.2,51.5 141,49 142.7,46.4 139.6,46.4 136.5,46.5 133.3,46.9 130.2,47.4 127.2,48 124.1,48.8 121.1,49.8 118.2,50.9 115.3,52.2 112.5,53.6 109.8,55.2 107.2,56.9 104.6,58.7 102.2,60.7 99.9,62.8 97.6,65 95.5,67.4 93.6,69.8 91.7,72.4 90,75 92,72.5 93.8,70 95.5,67.3 97,64.6 98.4,61.8 99.7,58.9 100.8,56 101.7,53 102.5,49.9 103.2,46.9 103.6,43.8 103.9,40.6 104.1,37.5 104.1,34.4 103.9,31.2 103.5,28.1 103,25 102.3,21.9 101.5,18.9 100.5,15.9 98.5,18.4 96.7,20.9 95,23.6 93.5,26.3 92.1,29.1 90.8,32 89.7,34.9 88.8,37.9 88,41 87.3,44.1 86.9,47.2 86.6,50.3 86.4,53.4 86.4,56.6 86.6,59.7 87,62.8 87.5,65.9 88.2,69 89,72 90,75 89.3,71.9 88.4,68.9 87.4,65.9 86.3,63 84.9,60.2 83.5,57.4 81.9,54.7 80.1,52.1 78.2,49.6 76.2,47.2 74.1,44.9 71.8,42.7 69.5,40.6 67,38.7 64.4,36.9 61.8,35.2 59,33.7 56.2,32.3 53.3,31 50.4,30 51.1,33 51.9,36 52.9,39 54.1,41.9 55.4,44.8 56.9,47.6 58.5,50.3 60.2,52.9 62.1,55.4 64.1,57.8 66.3,60.1 68.5,62.3 70.9,64.4 73.4,66.3 75.9,68.1 78.6,69.8 81.3,71.3 84.2,72.7 87.1,73.9 90,75 87.2,73.6 84.3,72.4 81.3,71.4 78.3,70.5 75.3,69.7 72.2,69.1 69.1,68.7 65.9,68.5 62.8,68.4 59.6,68.4 56.5,68.7 53.4,69.1 50.3,69.6 47.2,70.3 44.2,71.2 41.3,72.3 38.4,73.5 35.5,74.8 32.8,76.3 30.1,77.9 32.9,79.3 35.8,80.5 38.8,81.6 41.8,82.5 44.8,83.2 47.9,83.8 51,84.2 54.1,84.5 57.3,84.6 60.4,84.5 63.6,84.3 66.7,83.9 69.8,83.3 72.8,82.6 75.8,81.7 78.8,80.7 81.7,79.5 84.5,78.1 87.3,76.6 90,75 87.2,76.4 84.4,77.9 81.7,79.5 79.2,81.3 76.7,83.2 74.3,85.3 72,87.5 69.9,89.7 67.8,92.1 65.9,94.6 64.2,97.2 62.5,99.9 61,102.7 59.7,105.5 58.5,108.4 57.5,111.4 56.6,114.4 55.9,117.5 55.3,120.6 54.9,123.7 57.7,122.3 60.5,120.8 63.2,119.1 65.8,117.4 68.2,115.4 70.6,113.4 72.9,111.2 75,108.9 77.1,106.5 79,104 80.7,101.4 82.4,98.8 83.9,96 85.2,93.2" />'
#
# <g transform="rotate(205.3,85.2,93.2) translate(85.2, 93.2)">
#     <circle stroke="#63A375" stroke-width="2" fill="transparent" r="5.5" cx="0" cy="0"/>
#     <polygon points="0,12 2,9 -2,9" style="fill:#63A375;stroke:#63A375;stroke-width:2"/>
# </g>
#
# </svg>
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[93], line 7
#       3 jump(-60)
#       4 n = 7
#       5 radius = 60
#       6 angle = 60
# ----> 7 flower(n, radius, angle)
#       8
#       9 jump(120)
#      10 n = 9
#
# Cell In[92], line 4, in flower(n=7, radius=60, angle=60)
#       1 def flower(n, radius, angle):
#       2     """Draw a flower with n petals."""
#       3     for i in range(n):
# ----> 4         petal(radius, angle)
#       5         left(360 / n)
#
# Cell In[91], line 16, in petal(radius=60, angle=60)
#      13 def petal(radius, angle):
#      14     arc(radius, angle)
#      15     left(180 - angle)
# ---> 16     arc(radius, angle)
#      17     left(180 - angle)
#
# Cell In[91], line 11, in arc(radius=60, angle=60)
#       7     step_length = 2 * radius * math.sin(math.radians(angle / n) / 2)
#       8     step_angle = angle / n
#       9     for i in range(n):
#      10         forward(step_length)
# ---> 11         left(step_angle)
#
# File c:\Users\xxslo\AppData\Local\Programs\Python\Python314\Lib\site-packages\jupyturtle\jupyturtle.py:440, in _make_command.<locals>.command(*args=(3.0,))
#     438 def command(*args):
#     439     turtle = get_turtle()
# --> 440     method(turtle, *args)
#         turtle = <jupyturtle.jupyturtle.Turtle object at 0x00000203EEDDAA80>
#         method = <function Turtle.left at 0x00000203EEDE4EB0>
#         args = (3.0,)
# File c:\Users\xxslo\AppData\Local\Programs\Python\Python314\Lib\site-packages\jupyturtle\jupyturtle.py:303, in Turtle.left(self=<jupyturtle.jupyturtle.Turtle object>, degrees=3.0)
#     301 self.heading -= degrees
#     302 if self.animate:
# --> 303     self.draw()
#         self = <jupyturtle.jupyturtle.Turtle object at 0x00000203EEDDAA80>
# File c:\Users\xxslo\AppData\Local\Programs\Python\Python314\Lib\site-packages\jupyturtle\jupyturtle.py:240, in Turtle.draw(self=<jupyturtle.jupyturtle.Turtle object>)
#     238 if self.delay and self.animate:
#     239     time.sleep(self.delay)
# --> 240 h.update(HTML(self.get_SVG()))
#         h = <DisplayHandle display_id=1a27c5903d959067f678a6214023cc11>
#         self = <jupyturtle.jupyturtle.Turtle object at 0x00000203EEDDAA80>
# File ~\AppData\Roaming\Python\Python314\site-packages\ipykernel\zmqshell.py:149, in ZMQDisplayPublisher.publish(self=<ipykernel.zmqshell.ZMQDisplayPublisher object>, data={'text/html': '<svg width="300" height="150" style="fill:none; ...375;stroke:#63A375;stroke-width:2"/>\n</g>\n\n</svg>', 'text/plain': '<IPython.core.display.HTML object>'}, metadata={}, transient={'display_id': '1a27c5903d959067f678a6214023cc11'}, update=True, **kwargs={})
#     145     if outputs is not None:
#     146         outputs.setdefault(exec_count, []).append(
#     147             HistoryOutput(output_type="display_data", bundle=data)
#     148         )
# --> 149 self._flush_streams()
#         self = <ipykernel.zmqshell.ZMQDisplayPublisher object at 0x00000203EECD9E80>    150 if metadata is None:
#     151     metadata = {}
#
# File ~\AppData\Roaming\Python\Python314\site-packages\ipykernel\zmqshell.py:93, in ZMQDisplayPublisher._flush_streams(self=<ipykernel.zmqshell.ZMQDisplayPublisher object>)
#      91 def _flush_streams(self):
#      92     """flush IO Streams prior to display"""
# ---> 93     sys.stdout.flush()
#         sys.stdout = <ipykernel.iostream.OutStream object at 0x00000203ED4DD1E0>     94     sys.stderr.flush()
#
# File ~\AppData\Roaming\Python\Python314\site-packages\ipykernel\iostream.py:670, in OutStream.flush(self=<ipykernel.iostream.OutStream object>)
#     659 """trigger actual zmq send
#     660
#     661 send will happen in the background thread
#     662 """
#     663 if (
#     664     self.pub_thread
#     665     and self.pub_thread.thread is not None
#    (...)    668 ):
#     669     # request flush on the background thread
# --> 670     self.pub_thread.schedule(self._flush)
#         self.pub_thread = <ipykernel.iostream.IOPubThread object at 0x00000203ED4D1400>
#         self = <ipykernel.iostream.OutStream object at 0x00000203ED4DD1E0>    671     # wait for flush to actually get through, if we can.
#     672     evt = threading.Event()
#
# File ~\AppData\Roaming\Python\Python314\site-packages\ipykernel\iostream.py:339, in IOPubThread.schedule(self=<ipykernel.iostream.IOPubThread object>, f=<bound method OutStream._flush of <ipykernel.iostream.OutStream object>>)
#     337     self._events.append(f)
#     338     # wake event thread (message content is ignored)
# --> 339     self._event_pipe.send(b"")
#         self = <ipykernel.iostream.IOPubThread object at 0x00000203ED4D1400>    340 else:
#     341     f()
#
# File ~\AppData\Roaming\Python\Python314\site-packages\zmq\sugar\socket.py:698, in Socket.send(self=<zmq.Socket(zmq.PUSH)>, data=b'', flags=0, copy=True, track=False, routing_id=None, group=None)
#     691         data = zmq.Frame(
#     692             data,
#     693             track=track,
#     694             copy=copy or None,
#     695             copy_threshold=self.copy_threshold,
#     696         )
#     697     data.group = group
# --> 698 return super().send(data, flags=flags, copy=copy, track=track)
#         data = b''
#         flags = 0
#         copy = True
#         track = False
# File zmq/backend/cython/_zmq.py:1152
# -> 1152     def send(self, data, flags=0, copy: bint = True, track: bint = False):
#    1153         """
#    1154         Send a single zmq message frame on this socket.
#    1155
#
# File zmq/backend/cython/_zmq.py:1200
# -> 1200             return _send_copy(self.handle, data, flags)
#
# File zmq/backend/cython/_zmq.py:1468
# -> 1468             _check_rc(rc)
#
# File zmq/backend/cython/_zmq.py:179
# --> 179     PyErr_CheckSignals()
#
# KeyboardInterrupt:

# %%
# Solution goes here

# %% [markdown]
# ### Ask a virtual assistant
#
# There are several modules like `jupyturtle` in Python, and the one we used in this chapter has been customized for this book.
# So if you ask a virtual assistant for help, it won't know which module to use.
# But if you give it a few examples to work with, it can probably figure it out.
# For example, try this prompt and see if it can write a function that draws a spiral:
#
# ```
# The following program uses a turtle graphics module to draw a circle:
#
# from jupyturtle import make_turtle, forward, left
# import math
#
# def polygon(n, length):
#     angle = 360 / n
#     for i in range(n):
#         forward(length)
#         left(angle)
#
# def circle(radius):
#     circumference = 2 * math.pi * radius
#     n = 30
#     length = circumference / n
#     polygon(n, length)
#
# make_turtle(delay=0)
# circle(30)
#
# Write a function that draws a spiral.
# ```

# %% [markdown]
# Keep in mind that the result might use features we have not seen yet, and it might have errors.
# Copy the code from the VA and see if you can get it working.
# If you didn't get what you wanted, try modifying the prompt.

# %%
# Solution goes here

# %%
# Solution goes here

# %% [markdown]
# [Think Python: 3rd Edition](https://allendowney.github.io/ThinkPython/index.html)
#
# Copyright 2024 [Allen B. Downey](https://allendowney.com)
#
# Code license: [MIT License](https://mit-license.org/)
#
# Text license: [Creative Commons Attribution-NonCommercial-ShareAlike 4.0 International](https://creativecommons.org/licenses/by-nc-sa/4.0/)
