# %% [markdown]
# Name : Sulaiman Alfawzan

# %% [raw]
# ---
# title: "مسألة البحث في التوثيق"
# og:title: docs_random_problem
# toc: true
# format:
#   html: default
# ---

# %% [markdown]
# [![](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/HassanAlgoz/python/blob/main/book/exercises/docs_random_problem.ipynb)

# %% [markdown]
# **أهداف التمرين**:
#
# 1. ممارسة قراءة صفحات مراجع المكتبات البرمجية الأصلية
# 2. التعرف على إمكانات مكتبة العشوائية
# 3. ممارسة تركيب إجراء من أنواع مختلفة: الرقم والنص والتسلسل ونحو ذلك
# 4. التعرف على حقيقة شبه العشوائية (Pseudo-randomness) في الحواسيب
#
# مكتبة العشوائية `random` هي من ضمن المكتبات المبنية في لغة بايثون.

# %%
import random

# %% [markdown]
# بينما تحل المسائل التالية، ستحتاج إلى البحث في صفحة المكتبة. جرب أن تضع في محرك البحث العبارة:
#
# [`python 3 docs random`](https://www.google.com/search?q=python+3+docs+random&oq=python+3+docs+random)
#
# وستظهر في النتائج الأولى صفحة المكتبة في مراجع بايثون:
#
# ![صفحة مكتبة العشوائية](https://github.com/HassanAlgoz/python/blob/main/book/assets/python3-docs-random.png?raw=1){width="100%"}
#
# ولا أريد منك قراءة الصفحة كاملةً، ولذلك سأشير إلى بعض الأجزاء المهمة بالنسبة لنا الآن:
#
# 1. الإجراء: `random.seed` الذي تجده تحت قسم: Bookkeeping functions بالنظر في قائمة المحتويات في الجانب الأيسر من الصفحة
# 2. القسم: Functions for integers
# 3. القسم: Functions for sequences
# 4. القسم: Notes on Reproducibility
# 5. الأمثلة: Examples
#
# ## المسألة الأولى: توليد كلمة مرور
#
# اكتب إجراءً يقبل المعاملات التالية ليُنتِج **كلمة مرور** (Password):
#
# - الطول
# - الأحرف الصغيرة
# - الأحرف الكبيرة
# - الأرقام
# - الحد الأدنى من الأرقام
# - الرموز: `!@#$%^&*`
# - الحد الأدنى من الرموز
#
# ```python
# def generate_password(length: int, ...) -> str:
#     ...
# ```

# %%
def generate_password(
    length: int,
    lowercase: str = "abcdefghijklmnopqrstuvwxyz",
    uppercase: str = "ABCDEFGHIJKLMNOPQRSTUVWXYZ",
    digits: str = "0123456789",
    min_digits: int = 0,
    symbols: str = "!@#$%^&*",
    min_symbols: int = 0,
) -> str:
    if length <= 0:
        raise ValueError("length must be greater than 0")
    if min_digits <= 0 or min_symbols <= 0:
        raise ValueError("must be at least one digit or symbol")
    if min_symbols > 0 and not symbols:
        raise ValueError("the acceptable symbols are !@#$%^&*")

    pools = [p for p in (lowercase, uppercase, digits, symbols) if p]
    if not pools:
        raise ValueError("At least one character set must be provided")
    
    password_chars = []

    password_chars.extend(random.choice(digits) for _ in range(min_digits))
    password_chars.extend(random.choice(symbols) for _ in range(min_symbols))

    if len(password_chars) > length:
        raise ValueError("length is smaller than required minimum characters")

    all_chars = "".join(pools)
    remaining = length - len(password_chars)
    password_chars.extend(random.choice(all_chars) for _ in range(remaining))

    random.shuffle(password_chars)
    return "".join(password_chars)

# %%
print(generate_password(length=12, min_digits=1, min_symbols=1))
# Out:
# PZRTsfI7^i##

# %% [markdown]
# ## المسألة الثانية: توليد عبارة مرور
#
# اكتب إجراءً آخر يقبل المعاملات التالية ليُنتِج [**عبارة مرور** (Passphrase)](https://proton.me/blog/what-is-passphrase)، بحيث تكون سهلة الحفظ على البشر:
#
# - عدد الكلمات
# - فاصل الكلمات
# - تكبير الحرف الأول من كل كلمة
# - تضمين رقم
#
# ```python
# def ...
# ```

# %%
with open("words.txt") as f:
    words = f.read().split()

def generate_passphrase(
    num_words: int = 4,
    separator: str = "-",
    capitalize: bool = False,
    include_number: bool = False,
) -> str:
    chosen = [random.choice(words) for _ in range(num_words)]

    if capitalize:
        chosen = [w.capitalize() for w in chosen]

    if include_number:
        chosen.append(str(random.randint(0, 99)))

    return separator.join(chosen)

# %%
print(generate_passphrase(num_words=4, separator="-", capitalize=True, include_number=True))
# Out:
# Foulnesses-Revaccinating-Specialists-Fizzier-39
